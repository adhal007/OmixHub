# %%
import numpy as np
import scipy.stats as sp 
import pandas as pd 
import OutlierStatMethods.outlier_sum_stat_perm

# %% [markdown]
# ## 0. Generate pseudo datasets for disease and controls

# %%
np.random.seed(1234)
rng = np.random.default_rng()

# %%
disease_data = pd.DataFrame(rng.normal(2.0, 1, size=(50, 200)))
control_data = pd.DataFrame(rng.normal(1.0, 1, size=(50, 200)))

# %% [markdown]
# ## 1. Initialize subclass and apply Outlier Stat Methods

# %%
OSPerm_cls = OutlierStatMethods.outlier_sum_stat_perm.OSPerm(disease_data=disease_data, control_data=control_data)
# Out:
# 29/10//2023 05:18:1698580107 PM - DEBUG - OSPerm: Initialized OS Perm class

# %%
stats = OSPerm_cls.get_stats()
# Out:
# 29/10//2023 05:18:1698580107 PM - INFO - OSPerm.get_stats: Calculating median, mad and applying mad normalization
# 29/10//2023 05:18:1698580107 PM - INFO - OSPerm.get_stats: Generating null distribution
# 29/10//2023 05:18:1698580120 PM - INFO - OSPerm.get_stats: Consolidating stats into dictionary
# 29/10//2023 05:18:1698580120 PM - INFO - OSPerm.get_stats: Finished applying outlier stat methods

# %% [markdown]
# ## 2. Visualize and Interpret results

# %%
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(11.7,5.27)})
sns.set_style('white')
locs = np.arange(0, OSPerm_cls.no_of_feats,1)
y_vals = -np.log10(stats['pvalues'])
ax = sns.lineplot(x=locs, y=y_vals)
ax.axhline(-np.log10(0.05), linestyle='--', color='black', label='p<0.05 threshold')
ax.set_xlabel('feature')
ax.set_ylabel('-log10(p-value)')
ax.set_title('Differential features b/w cohorts in a NGS experiment (Signal Plot)')
ax.legend()

# %%
sns.set(rc={'figure.figsize':(8.7,7.27)})
sns.set_style('white')
x_vals = stats['OutlierSum']
y_vals = -np.log10(stats['pvalues'])
ax = sns.scatterplot(x=x_vals, y=y_vals)
ax.axhline(-np.log10(0.05), linestyle='--', color='black', label='p<0.05 threshold')
ax.set_xlabel('OutlierSum')
ax.set_ylabel('-log10(p-value)')
ax.set_title('Differential features b/w cohorts in a NGS experiment (Volcano Plot)')
ax.legend()
